# %%
# Method A: Import the entire module
import ml_math

result = ml_math.calculate_accuracy(90, 100)
print(f"Model Accuracy: {result}%")

# Method B: Import specific functions directly (Cleaner)
from ml_math import get_learning_rate

lr = get_learning_rate()
print(f"Current Learning Rate: {lr}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Method A: Import the entire module
# ----> 2 import ml_math
#       4 result = ml_math.calculate_accuracy(90, 100)
#       5 print(f"Model Accuracy: {result}%")
#
# ModuleNotFoundError: No module named 'ml_math'
