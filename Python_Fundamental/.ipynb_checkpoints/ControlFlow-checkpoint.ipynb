# %%
score = 85

if score >= 90:
    print("Excellent! You got an A.")
elif score >= 80:
    print("Great job! You got a B.")
elif score >= 70:
    print("Good effort! You got a C.")
else:
    print("Keep studying! You can do better.")
# Out:
# Great job! You got a B.

# %%
has_completed_assignment = True
attendance_percentage = 92

# Both conditions must be True to pass
if has_completed_assignment and attendance_percentage >= 75:
    print("Status: Eligible for Exam Unlock")
else:
    print("Status: Requirements Incomplete")
# Out:
# Status: Eligible for Exam Unlock
